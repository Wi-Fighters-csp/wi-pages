# %% [raw]
# ---
# layout: post
# title: The Lost Symphony
# description: A world-based orchestra adventure layout for the Poway Symphony Orchestra.
# permalink: /games/lost-symphony
# hide: true
# toc: false
# ---

# %% [markdown]
# ## The Lost Symphony
#
# This page now hosts the full structure for the larger Poway Symphony Orchestra game.
# The hub, section worlds, and Battle of the Sections mini-game are scaffolded so each world can be built one by one.
#
# - **Hub**: Grand Concert Hall overworld with section doors
# - **Worlds**: String Forest, Brass Fortress, Woodwind Wilds, Percussion Peaks
# - **Mini-game**: Battle of the Sections encounter scaffold inside each world
# - **Finale**: full orchestra reunion and PSO recording unlock

# %%
# %%html
#
# <div id="pso-lost-symphony-root"></div>

# %%
# %%js
#
# // GAME_RUNNER: The Lost Symphony | hide_edit: true, width: 100%, height: 1650px
#
# import { mountLostSymphonyGame } from '/assets/js/projects/lost-symphony/levels/LostSymphonyGame.js';
#
# mountLostSymphonyGame('pso-lost-symphony-root');
